# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
# My first 
# 我想在这个脚本中写一些代码，来实现python变量的

#定义变量
x=10
y=5
print("x=",x)
print("y=",y)

#定义一个函数
def add(a,b):
    return a+b  

# 变量的运算
print("x+y=",x+y)
print("x-y=",x-y)
print("x*y=",x*y)
print("x/y=",x/y)
# Out:
# x= 10
# y= 5
# x+y= 15
# x-y= 5
# x*y= 50
# x/y= 2.0
